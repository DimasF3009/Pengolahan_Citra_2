# %%
import numpy as np
import cv2 as cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("sawit.jpg")
opencvImg = cv2.add(img,100)
plt.imshow(opencvImg[:,:,::-1])
# Jika Anda ingin memastikan hasil penambahan sesuai dengan representasi gambar dan menghindari potensi perubahan yang tidak diinginkan, disarankan menggunakan fungsi OpenCV cv2.add().

# %%
img.shape
nparr = np.ones_like(img) * 100
opencvImg = cv2.add(img,nparr)
plt.imshow(opencvImg[:,:,::-1])
print(opencvImg.shape[0])
print(opencvImg.shape[1])
print(opencvImg.shape[2])
# jika blum mengetahui dimensi gambar pakai ini
# yaitu menambahkan intensitas warna pada setiap piksel gambar.
# Out:
# 390
# 780
# 3

# %%
plt.imshow(opencvImg[:,:,::-1])
npImg = img + nparr
